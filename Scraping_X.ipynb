# %%
twitter_auth_token = "ba4268c72bc492f50aeffc3b3a376601907bd7f4"

# %%
import pandas as pd

# %%
# !sudo apt-get purge -y nodejs npm
# !sudo rm -f /etc/apt/sources.list.d/nodesource.list
# !sudo apt-get autoremove -y
# !sudo apt-get autoclean -y

# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg

# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | \
  sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] \
https://deb.nodesource.com/node_20.x nodistro main" | \
  sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install -y nodejs

# !node -v
# !npm -v
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'npm' is not installed, so not removed
# Package 'nodejs' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,870 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,623 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,968 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,600 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:20 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Fetched 36.2 MB in 3s (10.7 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.21).
# The following additional packages will be installed:
#   dirmngr gnupg-l10n gnupg-utils gpg gpg-agent gpg-wks-client gpg-wks-server
#   gpgconf gpgsm gpgv
# Suggested packages:
#   pinentry-gnome3 tor parcimonie xloadimage scdaemon
# The following packages will be upgraded:
#   dirmngr gnupg gnupg-l10n gnupg-utils gpg gpg-agent gpg-wks-client
#   gpg-wks-server gpgconf gpgsm gpgv
# 11 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# Need to get 2,248 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg-wks-client amd64 2.2.27-3ubuntu2.5 [62.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dirmngr amd64 2.2.27-3ubuntu2.5 [293 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg-wks-server amd64 2.2.27-3ubuntu2.5 [57.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gnupg-utils amd64 2.2.27-3ubuntu2.5 [309 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg-agent amd64 2.2.27-3ubuntu2.5 [209 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg amd64 2.2.27-3ubuntu2.5 [519 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpgconf amd64 2.2.27-3ubuntu2.5 [94.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gnupg-l10n all 2.2.27-3ubuntu2.5 [54.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gnupg all 2.2.27-3ubuntu2.5 [315 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpgsm amd64 2.2.27-3ubuntu2.5 [197 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpgv amd64 2.2.27-3ubuntu2.5 [137 kB]
# Fetched 2,248 kB in 0s (6,449 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 11.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../00-gpg-wks-client_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg-wks-client (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../01-dirmngr_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking dirmngr (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../02-gpg-wks-server_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg-wks-server (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../03-gnupg-utils_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gnupg-utils (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../04-gpg-agent_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg-agent (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../05-gpg_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../06-gpgconf_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpgconf (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../07-gnupg-l10n_2.2.27-3ubuntu2.5_all.deb ...
# Unpacking gnupg-l10n (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../08-gnupg_2.2.27-3ubuntu2.5_all.deb ...
# Unpacking gnupg (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../09-gpgsm_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpgsm (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../10-gpgv_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpgv (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Setting up gpgv (2.2.27-3ubuntu2.5) ...
# Setting up gnupg-l10n (2.2.27-3ubuntu2.5) ...
# Setting up gpgconf (2.2.27-3ubuntu2.5) ...
# Setting up gpg (2.2.27-3ubuntu2.5) ...
# Setting up gnupg-utils (2.2.27-3ubuntu2.5) ...
# Setting up gpg-agent (2.2.27-3ubuntu2.5) ...
# Setting up gpgsm (2.2.27-3ubuntu2.5) ...
# Setting up dirmngr (2.2.27-3ubuntu2.5) ...
# Setting up gpg-wks-server (2.2.27-3ubuntu2.5) ...
# Setting up gpg-wks-client (2.2.27-3ubuntu2.5) ...
# Setting up gnupg (2.2.27-3ubuntu2.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg]  https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Get:5 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [13.8 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 26.0 kB in 1s (20.7 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 32.0 MB of archives.
# After this operation, 197 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.20.0-1nodesource1 [32.0 MB]
# Fetched 32.0 MB in 1s (62.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.20.0-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.20.0-1nodesource1) ...
# Setting up nodejs (20.20.0-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.20.0
# 10.8.2

# %%
# !npx playwright install --with-deps chromium
# Out:
# ⠙⠹⠸⠼⠴⠦╔═══════════════════════════════════════════════════════════════════════════════╗
# ║ WARNING: It looks like you are running 'npx playwright install' without first ║
# ║ installing your project's dependencies.                                       ║
# ║                                                                               ║
# ║ To avoid unexpected behavior, please install your dependencies first, and     ║
# ║ then run Playwright's install command:                                        ║
# ║                                                                               ║
# ║     npm install                                                               ║
# ║     npx playwright install                                                    ║
# ║                                                                               ║
# ║ If your project does not yet depend on Playwright, first install the          ║
# ║ applicable npm package (most commonly @playwright/test), and                  ║
# ║ then run Playwright's install command to download the browsers:               ║
# ║                                                                               ║
# ║     npm install @playwright/test                                              ║
# ║     npx playwright install                                                    ║
# ║                                                                               ║
# ╚═══════════════════════════════════════════════════════════════════════════════╝
# Installing dependencies...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.16).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   libatk1.0-data libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin
#   xfonts-encodings xfonts-utils
# Suggested packages:
#   libglib2.0-doc libgdk-pixbuf2.0-bin | libgdk-pixbuf2.0-dev libxml2-utils
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma at-spi2-core xdg-user-dirs
# The following NEW packages will be installed:
#   fonts-freefont-ttf fonts-ipafont-gothic fonts-noto-color-emoji
#   fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libxcomposite1 xfonts-cyrillic
#   xfonts-encodings xfonts-scalable xfonts-utils
# The following packages will be upgraded:
#   libglib2.0-0 libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin
# 4 upgraded, 15 newly installed, 0 to remove and 36 not upgraded.
# Need to get 32.1 MB of archives.
# After this operation, 68.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.7 [1,742 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.7 [117 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-bin amd64 2.72.4-0ubuntu2.7 [80.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-0 amd64 2.72.4-0ubuntu2.7 [1,467 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Fetched 32.1 MB in 1s (37.2 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 122891 files and directories currently installed.)
# Preparing to unpack .../00-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Preparing to unpack .../01-libglib2.0-dev_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../02-libglib2.0-dev-bin_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../03-libglib2.0-bin_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../04-libglib2.0-0_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../05-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../06-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../07-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-unifont.
# Preparing to unpack .../08-fonts-unifont_1%3a14.0.01-1_all.deb ...
# Unpacking fonts-unifont (1:14.0.01-1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../09-fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../10-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../11-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../12-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../13-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../14-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../15-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../16-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../17-xfonts-cyrillic_1%3a1.0.5_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.5) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../18-xfonts-scalable_1%3a1.0.3-1.2ubuntu1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.7) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.7) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.7) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.7) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# ⠙

# %%
filename = "Hasil_Scraping.csv"

search_keyword = (
    'Ruben Amorim,since:2025-09-01 until:2025-10-05 lang:id'
)

limit = 500





# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab LATEST -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: Ruben Amorim,since:2025-09-01 until:2025-10-05 lang:id
#
#  (2) (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 19
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 39
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 59
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 79
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 98
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 116
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 134
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 152
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 171
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 191
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 211
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 231
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 251
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 271
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 291
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 311
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 331
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 351
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 371
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 391
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 411
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 431
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 451
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 471
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 490
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Hasil_Scraping.csv
# Total tweets saved: 510
# Got 510 tweets, done scrolling...
# ⠙

# %%
file_path = f"tweets-data/{filename}"
df = pd.read_csv(file_path, delimiter=',')
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1974373474996269087  Sat Oct 04 07:18:13 +0000 2025               1
# 1    1974318066508136880  Sat Oct 04 04:49:42 +0000 2025               1
# 2    1974369202388807841  Sat Oct 04 07:01:14 +0000 2025               0
# 3    1974369054669340925  Sat Oct 04 07:00:39 +0000 2025               1
# 4    1974366374161158284  Sat Oct 04 06:50:00 +0000 2025               1
# ..                   ...                             ...             ...
# 505  1969020847634493742  Fri Sep 19 14:52:27 +0000 2025               0
# 506  1969049040878006502  Fri Sep 19 14:40:49 +0000 2025               0
# 507  1969046572102300002  Fri Sep 19 14:31:00 +0000 2025               0
# 508  1969046116378247494  Fri Sep 19 14:29:11 +0000 2025             606
# 509  1969033567297540345  Fri Sep 19 13:39:19 +0000 2025               0
#
#                                              full_text               id_str  \
# 0    Komentar Ruben Amorim Usai Banjir Kritik Legen...  1974373474996269087
# 1    @hayder_imron @PTKAIIndonesia Tak kirain Ruben...  1974336100421566960
# 2    Michael Carrick resmi konfirmasi kepulangannya...  1974369202388807841
# 3    #IMIKINO: Mu gihe hari amakuru avugwa ko Ruben...  1974369054669340925
# 4    Ruben Amorim sadar betul posisinya di Manchest...  1974366374161158284
# ..                                                 ...                  ...
# 505  @EmyuGarisNetral @utdfocusid Ya info ini benar...  1969051968137240638
# 506  Dalam konferensi pers nya Ruben Amorim mengata...  1969049040878006502
# 507  Bukan cuma lawan Chelsea Amorim juga harus had...  1969046572102300002
# 508   BREAKING : Ruben Amorim mengonfirmasi jika Ma...  1969046116378247494
# 509  Matheus Cunha dan Mason Mount dipastikan fit d...  1969033567297540345
#
#                                            image_url in_reply_to_screen_name  \
# 0    https://pbs.twimg.com/media/G2ZiNTqbwAAw2Z9.jpg                     NaN
# 1                                                NaN            hayder_imron
# 2                                                NaN                     NaN
# 3    https://pbs.twimg.com/media/G2ZeDKNW0AAEnoO.jpg                     NaN
# 4                                                NaN                     NaN
# ..                                               ...                     ...
# 505                                              NaN         EmyuGarisNetral
# 506  https://pbs.twimg.com/media/G1N3qtIbAAAzXtt.jpg                     NaN
# 507                                              NaN                     NaN
# 508  https://pbs.twimg.com/media/G1N1Ag8bIAAvaEY.jpg                     NaN
# 509  https://pbs.twimg.com/media/G1NpmA8a4AA9tEo.jpg                     NaN
#
#     lang  location  quote_count  reply_count  retweet_count  \
# 0     in       NaN            0            0              0
# 1     in       NaN            0            1              0
# 2     in       NaN            0            0              0
# 3     in       NaN            0            0              1
# 4     in       NaN            0            1              0
# ..   ...       ...          ...          ...            ...
# 505   in       NaN            0            0              0
# 506   in       NaN            0            0              0
# 507   in       NaN            0            0              0
# 508   in       NaN            4           42             15
# 509   in       NaN            0            0              0
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/undefined/status/197437347499626...             73674042
# 1    https://x.com/undefined/status/197433610042156...            324393557
# 2    https://x.com/undefined/status/197436920238880...  1578954814729248769
# 3    https://x.com/undefined/status/197436905466934...  1129245178101936129
# 4    https://x.com/undefined/status/197436637416115...             69183155
# ..                                                 ...                  ...
# 505  https://x.com/undefined/status/196905196813724...  1720665183188922368
# 506  https://x.com/undefined/status/196904904087800...  1617730217405210625
# 507  https://x.com/undefined/status/196904657210230...   940477788959555584
# 508  https://x.com/undefined/status/196904611637824...  1222927522033094656
# 509  https://x.com/undefined/status/196903356729754...  1270722365387714564
#
#      username
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 505       NaN
# 506       NaN
# 507       NaN
# 508       NaN
# 509       NaN
#
# [510 rows x 15 columns]
